# %%
import tarfile
# !wget https://storage.googleapis.com/i2l/data/dataset5.tgz
# !tar xf ./dataset5.tgz
with tarfile.open('dataset5.tgz', "r") as f:
        f.extractall()
# Out:
# --2023-03-11 14:51:37--  https://storage.googleapis.com/i2l/data/dataset5.tgz
# Resolving storage.googleapis.com (storage.googleapis.com)... 2607:f8b0:4007:818::2010, 2607:f8b0:4007:819::2010, 2607:f8b0:4007:817::2010, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|2607:f8b0:4007:818::2010|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 938920283 (895M) [application/gzip]
# Saving to: 'dataset5.tgz'
#
#      0K .......... .......... .......... .......... ..........  0% 1.85M 8m3s
#     50K .......... .......... .......... .......... ..........  0% 3.82M 5m59s
#    100K .......... .......... .......... .......... ..........  0% 5.52M 4m53s
#    150K .......... .......... .......... .......... ..........  0% 7.88M 4m8s
#    200K .......... .......... .......... .......... ..........  0% 7.84M 3m41s
#    250K .......... .......... .......... .......... ..........  0% 12.5M 3m16s
# ...

# %%
# !python main.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Cameron\Documents\CSE 251B\image-to-latex\main.py", line 1, in <module>
#     from experiment import Experiment
#   File "C:\Users\Cameron\Documents\CSE 251B\image-to-latex\experiment.py", line 13, in <module>
#     from model_factory import get_model
#   File "C:\Users\Cameron\Documents\CSE 251B\image-to-latex\model_factory.py", line 2, in <module>
#     from baseline_model import *
# ModuleNotFoundError: No module named 'baseline_model'
